# %% [markdown]
# <a href="https://colab.research.google.com/github/alghozi-ibad/belajar-koding/blob/main/DictionaryOperasi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
inventory = {
    "laptop": {"stok": 10, "harga": 15000000},
    "mouse": {"stok": 50, "harga": 250000},
    "monitor": {"stok": 20, "harga": 3000000}
}

# 1. Tambah produk baru
inventory["keyboard"] = {"stok": 30, "harga": 500000}

# 2. Update harga laptop
inventory["laptop"].update({"harga": 14500000})

# 3. Hitung total nilai gudang
total = 0

for barang in inventory:
    stok = inventory[barang]["stok"]
    harga = inventory[barang]["harga"]
    total += stok * harga

print("Total nilai gudang:", total)
# Out:
# Total nilai gudang: 232500000
