# %% [markdown]
# <a href="https://colab.research.google.com/github/alghozi-ibad/belajar-koding/blob/main/PandasDataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

df_data = {
    'Nama': ['Andi', 'Budi', 'Caca', 'Dedi', 'Euis'],
    'Departemen': ['IT', 'HR', 'IT', 'Sales', 'Sales'],
    'Gaji': [8000000, 7000000, 8500000, np.nan, 6000000],
    'Pengalaman_Tahun': [5, 3, 6, 2, 1]
}

df = pd.DataFrame(df_data)
print("=== Data Awal ===")
print(df)

median_gaji = df['Gaji'].median()
df['Gaji'] = df['Gaji'].fillna(median_gaji)

print("\n=== Setelah Isi NaN dengan Median ===")
print(df)

df['Kategori_Senioritas'] = np.where(
    df['Pengalaman_Tahun'] > 4,
    'Senior',
    'Junior'
)

print("\n=== Setelah Tambah Kategori ===")
print(df)

rata_gaji = df.groupby('Departemen')['Gaji'].mean()

print("\n=== Rata-rata Gaji per Departemen ===")
print(rata_gaji)
# Out:
# === Data Awal ===
#    Nama Departemen       Gaji  Pengalaman_Tahun
# 0  Andi         IT  8000000.0                 5
# 1  Budi         HR  7000000.0                 3
# 2  Caca         IT  8500000.0                 6
# 3  Dedi      Sales        NaN                 2
# 4  Euis      Sales  6000000.0                 1
#
# === Setelah Isi NaN dengan Median ===
#    Nama Departemen       Gaji  Pengalaman_Tahun
# 0  Andi         IT  8000000.0                 5
# 1  Budi         HR  7000000.0                 3
# 2  Caca         IT  8500000.0                 6
# 3  Dedi      Sales  7500000.0                 2
# 4  Euis      Sales  6000000.0                 1
#
# === Setelah Tambah Kategori ===
#    Nama Departemen       Gaji  Pengalaman_Tahun Kategori_Senioritas
# 0  Andi         IT  8000000.0                 5              Senior
# 1  Budi         HR  7000000.0                 3              Junior
# 2  Caca         IT  8500000.0                 6              Senior
# 3  Dedi      Sales  7500000.0                 2              Junior
# 4  Euis      Sales  6000000.0                 1              Junior
#
# === Rata-rata Gaji per Departemen ===
# Departemen
# HR       7000000.0
# IT       8250000.0
# Sales    6750000.0
# Name: Gaji, dtype: float64
