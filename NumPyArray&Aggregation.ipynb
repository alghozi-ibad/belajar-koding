# %% [markdown]
# <a href="https://colab.research.google.com/github/alghozi-ibad/belajar-koding/blob/main/NumPyArray%26Aggregation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

scores = np.array([
    [80, 85, 90],
    [70, 60, 75],
    [95, 90, 100],
    [40, 50, 45]
])

# 1. Rata-rata tiap mahasiswa (axis=1)
rata_per_mahasiswa = np.mean(scores, axis=1)
print("Rata-rata per mahasiswa:", rata_per_mahasiswa)

# 2. Nilai tertinggi
nilai_tertinggi = np.max(scores)
print("Nilai tertinggi:", nilai_tertinggi)

# 3. Status lulus / gagal
status = np.where(rata_per_mahasiswa >= 70, "Lulus", "Gagal")
print("Status:", status)
# Out:
# Rata-rata per mahasiswa: [85.         68.33333333 95.         45.        ]
# Nilai tertinggi: 100
# Status: ['Lulus' 'Gagal' 'Lulus' 'Gagal']
